# %% [markdown]
# # Airline Passenger Satisfaction
#
#
# This dataset is given by an airline organization, but it's actual name is not given due to various purposes.
# I use this dataset to create dashboard to uncover insights in improving customer experience and operational efficiency at Airline X.
#
# Before using this dataset to create dashboard, I conducted data investigation and data cleaning so that the data which will be visualized represent the actual condition.
#
# The source of this dataset is: https://www.kaggle.com/datasets/sjleshrac/airlines-customer-satisfaction/data

# %%
# import libraries
import numpy as np
import pandas as pd

# %%
# load the dataset
data = pd.read_csv(r"E:\Infinite Case Study\airline_customer_satisfaction.csv")

# %%
# view the data
data.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %%
# explore the size of the data
data.shape
# Out:
# (129880, 23)

# %% [markdown]
# There are 129880 rows and 23 columns in the dataset.

# %%
# check the data types
data.dtypes
# Out:
# satisfaction                          object
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Seat comfort                           int64
# Departure/Arrival time convenient      int64
# Food and drink                         int64
# Gate location                          int64
# Inflight wifi service                  int64
# Inflight entertainment                 int64
# Online support                         int64
# Ease of Online booking                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Cleanliness                            int64
# Online boarding                        int64
# ...

# %%
# check for missing values
data.isna().sum()
# Out:
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# ...

# %% [markdown]
# There are only 393 missing values out of the 129880 values. Since this is a tiny percentage of the total, I will proceed to drop these rows.

# %%
# delete missing values
data.dropna(axis=0).reset_index(drop=True)
# Out:
#         satisfaction  Gender      Customer Type  Age   Type of Travel  \
# 0          satisfied  Female     Loyal Customer   65  Personal Travel
# 1          satisfied    Male     Loyal Customer   47  Personal Travel
# 2          satisfied  Female     Loyal Customer   15  Personal Travel
# 3          satisfied  Female     Loyal Customer   60  Personal Travel
# 4          satisfied  Female     Loyal Customer   70  Personal Travel
# ...              ...     ...                ...  ...              ...
# 129482     satisfied  Female  disloyal Customer   29  Personal Travel
# 129483  dissatisfied    Male  disloyal Customer   63  Personal Travel
# 129484  dissatisfied    Male  disloyal Customer   69  Personal Travel
# 129485  dissatisfied    Male  disloyal Customer   66  Personal Travel
# 129486  dissatisfied  Female  disloyal Customer   38  Personal Travel
#
#            Class  Flight Distance  Seat comfort  \
# 0            Eco              265             0
# ...

# %%
# investigate descriptive statistics
data.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %% [markdown]
# The descriptive statistics seems nice, there is no outlier in most of the data. We can proceed to use this data for dashboard visualization.

# %%
# save the cleaned_data as csv file
cleaned_data = data.to_csv(r"E:\Infinite Case Study\cleaned_data_airline.csv", index=False)
